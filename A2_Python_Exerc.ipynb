# %% [markdown]
# <a href="https://colab.research.google.com/github/ggpgutierrez/IA_2022S2/blob/main/A2_Python_Exerc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <head>
#   <meta name="author" content="Rogério de Oliveira">
#   <meta institution="author" content="Universidade Presbiteriana Mackenzie">
# </head>
#
# <img src="http://meusite.mackenzie.br/rogerio/mackenzie_logo/UPM.2_horizontal_vermelho.jpg" width=300, align="right">
#
#
#
# <br>
# <br>
#
# <br>
# <br>
#
#
# <br>
# <br>
#
# ---

# %% [markdown]
# # Exercícios

# %% [markdown]
# Em todos os exercícios execute o código abaixo como a primeira instrução e uma única vez para gerar os valores de `letras` e `lista`.
#
# Todos exercícios possuem várias soluções possíveis, mas não se preocupe com isso. A melhor solução é primeiro, a que funciona para você!

# %%
import numpy as np
import random
from random import choices
import string

random.seed(1234)
letras = choices(string.ascii_lowercase,k=100)
lista = random.sample(range(1, 10000), 1000)
print(np.array(lista).sum() == 5244799) # precisa retornar True!
# Out:
# True

# %% [markdown]
# 1. Dos valores [9887, 3233, 813] qual o índice dos valores presentes em  `lista`?

# %%
# seu código

# %% [markdown]
# 2. Quais os dois primeiros valores maiores que 2046 em `lista`?

# %%
# seu código
i = 0
lista.sort()
for listas in lista:
  if( i < 2):
    if(listas >= 2046):
      print(listas)
      i+= 1
# Out:
# 2055
# 2064

# %% [markdown]
# 3. Quais os valores mínimo e máximo em `lista`?

# %%
# seu código

menor = min(lista)
maior = max(lista)

print(menor)
print(maior)
# Out:
# 4
# 9998

# %% [markdown]
# 4. Quais as 4 letras que mais aparecem em `letras`?
#
# <small> ( Existe várias formas de fazer isso, mas fica aqui a sugestão: se você implementar um dicionário *letra:quantidade* poderá empregar a mesma solução na tarefa de aprofundamento! ) </small>

# %%
# seu código

# %% [markdown]
# 5. Qual a soma dos valores pares de `lista`?

# %%
# seu código
soma = 0
for listas in lista:
  if(listas%2 == 0):
    print("O número ",listas," é par")
    soma += listas


print("Soma dos números pares é ", soma)
# Out:
# O número  4  é par
# O número  28  é par
# O número  110  é par
# O número  140  é par
# O número  144  é par
# O número  146  é par
# O número  182  é par
# O número  244  é par
# O número  272  é par
# O número  276  é par
# O número  280  é par
# O número  290  é par
# O número  292  é par
# O número  294  é par
# O número  296  é par
# O número  298  é par
# O número  342  é par
# O número  428  é par
# O número  446  é par
# O número  458  é par
# O número  464  é par
# O número  472  é par
# O número  482  é par
# O número  512  é par
# O número  518  é par
# O número  530  é par
# O número  542  é par
# O número  596  é par
# O número  614  é par
# O número  636  é par
# O número  654  é par
# O número  668  é par
# O número  670  é par
# O número  680  é par
# O número  690  é par
# O número  732  é par
# O número  742  é par
# O número  764  é par
# O número  784  é par
# O número  788  é par
# O número  812  é par
# O número  816  é par
# O número  858  é par
# O número  860  é par
# O número  948  é par
# O número  960  é par
# O número  982  é par
# O número  1012  é par
# O número  1020  é par
# O número  1034  é par
# O número  1036  é par
# O número  1046  é par
# O número  1086  é par
# O número  1118  é par
# O número  1120  é par
# O número  1126  é par
# O número  1134  é par
# O número  1150  é par
# O número  1162  é par
# O número  1186  é par
# O número  1188  é par
# O número  1202  é par
# O número  1224  é par
# O número  1240  é par
# O número  1262  é par
# O número  1290  é par
# O número  1314  é par
# O número  1328  é par
# O número  1332  é par
# O número  1348  é par
# O número  1358  é par
# O número  1392  é par
# O número  1436  é par
# O número  1440  é par
# O número  1448  é par
# O número  1462  é par
# O número  1478  é par
# O número  1490  é par
# O número  1512  é par
# O número  1522  é par
# O número  1554  é par
# O número  1558  é par
# O número  1562  é par
# O número  1580  é par
# O número  1586  é par
# O número  1658  é par
# O número  1660  é par
# O número  1700  é par
# O número  1726  é par
# O número  1728  é par
# O número  1748  é par
# O número  1768  é par
# O número  1822  é par
# O número  1828  é par
# O número  1864  é par
# O número  1960  é par
# O número  1974  é par
# O número  2016  é par
# O número  2030  é par
# O número  2064  é par
# O número  2082  é par
# O número  2118  é par
# O número  2146  é par
# O número  2154  é par
# O número  2174  é par
# O número  2190  é par
# O número  2210  é par
# O número  2244  é par
# O número  2246  é par
# O número  2294  é par
# O número  2318  é par
# O número  2340  é par
# O número  2342  é par
# O número  2372  é par
# O número  2374  é par
# O número  2402  é par
# O número  2424  é par
# O número  2430  é par
# O número  2502  é par
# O número  2508  é par
# O número  2540  é par
# O número  2558  é par
# O número  2576  é par
# O número  2586  é par
# O número  2592  é par
# O número  2598  é par
# O número  2604  é par
# O número  2616  é par
# O número  2642  é par
# O número  2662  é par
# O número  2686  é par
# O número  2692  é par
# O número  2748  é par
# O número  2750  é par
# O número  2778  é par
# O número  2806  é par
# O número  2852  é par
# O número  2902  é par
# O número  2992  é par
# O número  2994  é par
# O número  3000  é par
# O número  3014  é par
# O número  3040  é par
# O número  3086  é par
# O número  3142  é par
# O número  3146  é par
# O número  3184  é par
# O número  3188  é par
# O número  3212  é par
# O número  3224  é par
# O número  3236  é par
# O número  3248  é par
# O número  3286  é par
# O número  3292  é par
# O número  3308  é par
# O número  3360  é par
# O número  3376  é par
# O número  3380  é par
# O número  3394  é par
# O número  3410  é par
# O número  3420  é par
# O número  3470  é par
# O número  3472  é par
# O número  3478  é par
# O número  3482  é par
# O número  3544  é par
# O número  3556  é par
# O número  3570  é par
# O número  3574  é par
# O número  3598  é par
# O número  3660  é par
# O número  3676  é par
# O número  3762  é par
# O número  3780  é par
# O número  3802  é par
# O número  3810  é par
# O número  3872  é par
# O número  3874  é par
# O número  3884  é par
# O número  3892  é par
# O número  3916  é par
# O número  3966  é par
# O número  3986  é par
# O número  3988  é par
# O número  4050  é par
# O número  4078  é par
# O número  4092  é par
# O número  4174  é par
# O número  4180  é par
# O número  4210  é par
# O número  4214  é par
# O número  4218  é par
# O número  4256  é par
# O número  4266  é par
# O número  4280  é par
# O número  4284  é par
# O número  4294  é par
# O número  4300  é par
# O número  4372  é par
# O número  4398  é par
# O número  4402  é par
# O número  4404  é par
# O número  4470  é par
# O número  4472  é par
# O número  4480  é par
# O número  4534  é par
# O número  4556  é par
# O número  4568  é par
# O número  4570  é par
# O número  4572  é par
# O número  4618  é par
# O número  4674  é par
# O número  4690  é par
# O número  4700  é par
# O número  4726  é par
# O número  4746  é par
# O número  4770  é par
# O número  4772  é par
# O número  4776  é par
# O número  4786  é par
# O número  4800  é par
# O número  4804  é par
# O número  4814  é par
# O número  4858  é par
# O número  4874  é par
# O número  4876  é par
# O número  4884  é par
# O número  4890  é par
# O número  4912  é par
# O número  4932  é par
# O número  4938  é par
# O número  4960  é par
# O número  4990  é par
# O número  5000  é par
# O número  5008  é par
# O número  5036  é par
# O número  5046  é par
# O número  5104  é par
# O número  5108  é par
# O número  5140  é par
# O número  5148  é par
# O número  5164  é par
# O número  5178  é par
# O número  5182  é par
# O número  5188  é par
# O número  5194  é par
# O número  5210  é par
# O número  5226  é par
# O número  5236  é par
# O número  5280  é par
# O número  5296  é par
# O número  5304  é par
# O número  5316  é par
# O número  5320  é par
# O número  5330  é par
# O número  5336  é par
# O número  5350  é par
# O número  5356  é par
# O número  5384  é par
# O número  5392  é par
# O número  5414  é par
# O número  5434  é par
# O número  5436  é par
# O número  5484  é par
# O número  5494  é par
# O número  5496  é par
# O número  5504  é par
# O número  5512  é par
# O número  5532  é par
# O número  5540  é par
# O número  5556  é par
# O número  5570  é par
# O número  5576  é par
# O número  5602  é par
# O número  5614  é par
# O número  5616  é par
# O número  5618  é par
# O número  5654  é par
# O número  5660  é par
# O número  5672  é par
# O número  5674  é par
# O número  5698  é par
# O número  5776  é par
# O número  5780  é par
# O número  5798  é par
# O número  5816  é par
# O número  5818  é par
# O número  5824  é par
# O número  5862  é par
# O número  5882  é par
# O número  5890  é par
# O número  5900  é par
# O número  5924  é par
# O número  5946  é par
# O número  5956  é par
# O número  5974  é par
# O número  5982  é par
# O número  6028  é par
# O número  6048  é par
# O número  6086  é par
# O número  6090  é par
# O número  6092  é par
# O número  6096  é par
# O número  6110  é par
# O número  6112  é par
# O número  6144  é par
# O número  6150  é par
# O número  6152  é par
# O número  6154  é par
# O número  6178  é par
# O número  6190  é par
# O número  6210  é par
# O número  6216  é par
# O número  6222  é par
# O número  6246  é par
# O número  6306  é par
# O número  6318  é par
# O número  6362  é par
# O número  6406  é par
# O número  6414  é par
# O número  6426  é par
# O número  6442  é par
# O número  6472  é par
# O número  6476  é par
# O número  6506  é par
# O número  6512  é par
# O número  6562  é par
# O número  6580  é par
# O número  6608  é par
# O número  6626  é par
# O número  6644  é par
# O número  6650  é par
# O número  6660  é par
# O número  6688  é par
# O número  6690  é par
# O número  6692  é par
# O número  6708  é par
# O número  6722  é par
# O número  6732  é par
# O número  6738  é par
# O número  6740  é par
# O número  6744  é par
# O número  6770  é par
# O número  6800  é par
# O número  6840  é par
# O número  6852  é par
# O número  6868  é par
# O número  6874  é par
# O número  6890  é par
# O número  6910  é par
# O número  6920  é par
# O número  6944  é par
# O número  6950  é par
# O número  6960  é par
# O número  6968  é par
# O número  6998  é par
# O número  7028  é par
# O número  7098  é par
# O número  7120  é par
# O número  7134  é par
# O número  7140  é par
# O número  7166  é par
# O número  7214  é par
# O número  7242  é par
# O número  7246  é par
# O número  7248  é par
# O número  7268  é par
# O número  7280  é par
# O número  7292  é par
# O número  7296  é par
# O número  7302  é par
# O número  7306  é par
# O número  7326  é par
# O número  7342  é par
# O número  7366  é par
# O número  7384  é par
# O número  7392  é par
# O número  7408  é par
# O número  7422  é par
# O número  7444  é par
# O número  7450  é par
# O número  7462  é par
# O número  7486  é par
# O número  7520  é par
# O número  7530  é par
# O número  7590  é par
# O número  7630  é par
# O número  7666  é par
# O número  7680  é par
# O número  7682  é par
# O número  7690  é par
# O número  7720  é par
# O número  7734  é par
# O número  7774  é par
# O número  7786  é par
# O número  7796  é par
# O número  7798  é par
# O número  7800  é par
# O número  7832  é par
# O número  7858  é par
# O número  7868  é par
# O número  7896  é par
# O número  7944  é par
# O número  7954  é par
# O número  7956  é par
# O número  7966  é par
# O número  7998  é par
# O número  8004  é par
# O número  8018  é par
# O número  8028  é par
# O número  8034  é par
# O número  8072  é par
# O número  8074  é par
# O número  8090  é par
# O número  8140  é par
# O número  8186  é par
# O número  8188  é par
# O número  8210  é par
# O número  8222  é par
# O número  8242  é par
# O número  8244  é par
# O número  8264  é par
# O número  8274  é par
# O número  8290  é par
# O número  8296  é par
# O número  8298  é par
# O número  8330  é par
# O número  8376  é par
# O número  8400  é par
# O número  8408  é par
# O número  8480  é par
# O número  8490  é par
# O número  8494  é par
# O número  8496  é par
# O número  8502  é par
# O número  8504  é par
# O número  8510  é par
# O número  8556  é par
# O número  8560  é par
# O número  8566  é par
# O número  8600  é par
# O número  8614  é par
# O número  8644  é par
# O número  8680  é par
# O número  8686  é par
# O número  8694  é par
# O número  8698  é par
# O número  8722  é par
# O número  8750  é par
# O número  8784  é par
# O número  8790  é par
# O número  8802  é par
# O número  8834  é par
# O número  8856  é par
# O número  8858  é par
# O número  8876  é par
# O número  8906  é par
# O número  8914  é par
# O número  8952  é par
# O número  8968  é par
# O número  8972  é par
# O número  8980  é par
# O número  8996  é par
# O número  9010  é par
# O número  9098  é par
# O número  9100  é par
# O número  9102  é par
# O número  9136  é par
# O número  9138  é par
# O número  9146  é par
# O número  9178  é par
# O número  9198  é par
# O número  9204  é par
# O número  9214  é par
# O número  9222  é par
# O número  9244  é par
# O número  9276  é par
# O número  9306  é par
# O número  9312  é par
# O número  9318  é par
# O número  9372  é par
# O número  9386  é par
# O número  9392  é par
# O número  9412  é par
# O número  9434  é par
# O número  9450  é par
# O número  9454  é par
# O número  9466  é par
# O número  9478  é par
# O número  9482  é par
# O número  9496  é par
# O número  9500  é par
# O número  9504  é par
# O número  9518  é par
# O número  9586  é par
# O número  9616  é par
# O número  9626  é par
# O número  9628  é par
# O número  9634  é par
# O número  9654  é par
# O número  9664  é par
# O número  9680  é par
# O número  9692  é par
# O número  9706  é par
# O número  9738  é par
# O número  9794  é par
# O número  9802  é par
# O número  9818  é par
# O número  9866  é par
# O número  9888  é par
# O número  9892  é par
# O número  9942  é par
# O número  9980  é par
# O número  9988  é par
# O número  9990  é par
# O número  9996  é par
# O número  9998  é par
# Soma dos números pares é  2687196
